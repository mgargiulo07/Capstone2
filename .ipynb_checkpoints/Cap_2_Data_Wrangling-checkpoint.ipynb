# %%
#Packages
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Importing Raw Data
bakers = pd.read_csv("https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2022/2022-10-25/bakers.csv")
challenges = pd.read_csv("https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2022/2022-10-25/challenges.csv")
ratings = pd.read_csv("https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2022/2022-10-25/ratings.csv")
episodes = pd.read_csv("https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2022/2022-10-25/episodes.csv")

# %% [markdown]
# ## Bakers DataFrame

# %% [markdown]
# Order of operations for cleaning up the bakers dataframe:
# 1. Explore the data with .info, .describe, and .shape
# 2. Change Datatypes of int -> categories

# %% [markdown]
# ## Bakers DF Notes
#
# 1. Series needs to changed to a category
# 2. baker can be removed. we can use baker_full to get the first and last name
# 3. star_baker is a null category (no data provided)-- can be removed

# %%
bakers.info()
bakers.describe()
bakers.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 24 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   series                     120 non-null    int64
#  1   baker                      120 non-null    object
#  2   star_baker                 120 non-null    int64
#  3   technical_winner           120 non-null    int64
#  4   technical_top3             120 non-null    int64
#  5   technical_bottom           120 non-null    int64
#  6   technical_highest          119 non-null    float64
#  7   technical_lowest           119 non-null    float64
#  8   technical_median           119 non-null    float64
#  9   series_winner              120 non-null    int64
#  10  series_runner_up           120 non-null    int64
#  11  total_episodes_appeared    120 non-null    int64
#  12  first_date_appeared        95 non-null     object
# ...

# %%
bakers['series_cat'] = bakers['series'].astype('category')

# %%
assert bakers['series_cat'].dtype =='category'

# %%
bakers.describe()
# Out:
#            series  star_baker  technical_winner  technical_top3  \
# count  120.000000       120.0        120.000000      120.000000
# mean     5.600000         0.0          0.775000        2.325000
# std      2.856218         0.0          0.991243        2.312416
# min      1.000000         0.0          0.000000        0.000000
# 25%      3.000000         0.0          0.000000        0.000000
# 50%      6.000000         0.0          0.000000        2.000000
# 75%      8.000000         0.0          1.000000        4.000000
# max     10.000000         0.0          5.000000        8.000000
#
#        technical_bottom  technical_highest  technical_lowest  \
# count        120.000000         119.000000        119.000000
# mean           3.475000           3.260504          8.915966
# std            1.680149           3.261127          2.048480
# min            0.000000           1.000000          4.000000
# 25%            2.000000           1.000000          7.000000
# ...

# %%
bakers.star_baker.unique()
# Out:
# array([0])

# %%
bakers[bakers.technical_highest.isna()]
# Out:
#    series baker  star_baker  technical_winner  technical_top3  \
# 7       1  Mark           0                 0               0
#
#    technical_bottom  technical_highest  technical_lowest  technical_median  \
# 7                 0                NaN               NaN               NaN
#
#    series_winner  ...  first_date_us  last_date_us percent_episodes_appeared  \
# 7              0  ...            NaN           NaN                 16.666667
#
#   percent_technical_top3     baker_full  age  occupation     hometown  \
# 7                    0.0  Mark Whithers   48  Bus Driver  South Wales
#
#   baker_last  baker_first
# 7   Whithers         Mark
#
# [1 rows x 24 columns]

# %%
# Out:
#    series      baker  star_baker  technical_winner  technical_top3  \
# 0       1    Annetha           0                 0               1
# 1       1      David           0                 0               1
# 2       1        Edd           0                 2               4
# 3       1  Jasminder           0                 0               2
# 4       1   Jonathan           0                 1               1
# 5       1        Lea           0                 0               0
# 6       1     Louise           0                 0               0
# 7       1       Mark           0                 0               0
# 8       1    Miranda           0                 2               4
# 9       1       Ruth           0                 0               2
#
#    technical_bottom  technical_highest  technical_lowest  technical_median  \
# 0                 1                2.0               7.0               4.5
# 1                 3                3.0               8.0               4.5
# ...

# %%
episodes[episodes.series ==1]
# Out:
#    series  episode  bakers_appeared  bakers_out  bakers_remaining  \
# 0       1        1               10           2                 8
# 1       1        2                8           2                 6
# 2       1        3                6           1                 5
# 3       1        4                5           1                 4
# 4       1        5                4           1                 3
# 5       1        6                3           0                 3
#
#    star_bakers  technical_winners sb_name winner_name       eliminated
# 0            0                  1     NaN         NaN        Lea, Mark
# 1            0                  1     NaN         NaN  Annetha, Louise
# 2            0                  1     NaN         NaN         Jonathan
# 3            0                  1     NaN         NaN            David
# 4            0                  1     NaN         NaN        Jasminder
# 5            0                  0     NaN         Edd              NaN
